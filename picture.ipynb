# %%
# %matplotlib inline
import numpy 
import cv2
from matplotlib import pyplot as plt
img = cv2.imread("n1.jpg")
print img
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...,
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e0e5cb53fd48> in <module>()
#       7 plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#       8 plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
# ----> 9 plt.show(img)
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# c:\python27\lib\site-packages\ipykernel\pylab\backend_inline.pyc in show(close)
#      35         # only call close('all') if any to close
#      36         # close triggers gc.collect, which can be slow
# ---> 37         if close and Gcf.get_all_fig_managers():
#      38             matplotlib.pyplot.close('all')
#      39
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#%matplotlib inline
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread("n1.jpg")
kernel = np.ones((4,4),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
#dilation = cv2.dilate(img,kernel,iterations = 1)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

blurred =cv2.GaussianBlur(erosion,(5,5),0)
edged = cv2.Canny(blurred,300,300)
dilation = cv2.dilate(edged,kernel,iterations = 8)


plt.imshow(dilation)
